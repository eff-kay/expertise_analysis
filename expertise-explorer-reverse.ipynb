# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as pt
import json
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_colwidth', -1)

# %%
import pickle
df = pd.read_pickle("projectData/authorExperienceMatrix.p")
dF = pd.DataFrame(df.items())
# df=df.sort_index(axis=0 ,ascending=False)
# df= df.reset_index(drop=True)

dF
# Out:
#                                                                    0    1
# 0     (Owen O'Malley, 5128a9a453d64bfe1ed978cf9ffed27985eeef36)       1
# 1     (Owen O'Malley, c94ff0f240de583311c1bd73cf41d113ade75ebf)       2
# 2     (Owen O'Malley, abe7be913432053f6d419ea4ca4f9cd2be938bc7)       3
# 3     (Owen O'Malley, cab0a4bf543f58600ae8499f5b219a452f89c827)       4
# 4     (Owen O'Malley, c967cef4d3b82bf05f09ff03ff50243e0a81db26)       5
# 5     (Owen O'Malley, 95a0db602b2e0606af11d666d9d10d64766f9ecf)       6
# 6     (Giridharan Kesavan, ac670cc47f06b0eb880dcb5522a5aba187b5c67d)  1
# 7     (Giridharan Kesavan, bd524bd9608fa6387623cfe492572722c0477470)  2
# 8     (Giridharan Kesavan, a72da1135b3362b641f751afa2c93962bd9ac746)  3
# 9     (Giridharan Kesavan, 7e7fd2ce5b754c6398f8a326e5172d1e1b57c8e6)  4
# ...                                                              ... ..
# 9704  (rohithsharmaks, dc76c4b035277f276bc575222d1536e199d719d7)      5
# 9705  (Vinayakumar B, f8932d478f5cbdc536559e06d539cd39b11eff33)       115
# 9706  (Arun Suresh, 84ea7cd40883871caa657b154db9f6ab206b4ad3)         15
# 9707  (Junping Du, 7af531d2e393185fa7dd32370f45dbb2a1d34df5)          76
# 9708  (Junping Du, c8469357bad481ca8e341050553a5ae6d98bf8e5)          77
# 9709  (Jing Zhao, 2c694286b4a312bf3920c5b27e167af6ef66e13b)           237
# 9710  (Jing Zhao, d7d804623eb193fe27d690e374824622ba3d3a25)           238
# 9711  (Carlo Curino, 8e23a7997fcc0fc17ee9725324ad745ec4b406e1)        1
# 9712  (Arpit Agarwal, 42a05d29eeb61c6c01cfa56142bb05f38e162707)       198
# 9713  (Rohith Sharma K S, a0da1ec01051108b77f86799dd5e97563b2a3962)   2
#
# [9714 rows x 2 columns]

# %%
dF.columns= ["name", "experience"]
dF[['name','commits']]= pd.DataFrame(dF.name.tolist(), index=dF.index)
experienceCommits = dF
experienceCommits
# Out:
#                     name  experience                                   commits
# 0     Owen O'Malley       1           5128a9a453d64bfe1ed978cf9ffed27985eeef36
# 1     Owen O'Malley       2           c94ff0f240de583311c1bd73cf41d113ade75ebf
# 2     Owen O'Malley       3           abe7be913432053f6d419ea4ca4f9cd2be938bc7
# 3     Owen O'Malley       4           cab0a4bf543f58600ae8499f5b219a452f89c827
# 4     Owen O'Malley       5           c967cef4d3b82bf05f09ff03ff50243e0a81db26
# 5     Owen O'Malley       6           95a0db602b2e0606af11d666d9d10d64766f9ecf
# 6     Giridharan Kesavan  1           ac670cc47f06b0eb880dcb5522a5aba187b5c67d
# 7     Giridharan Kesavan  2           bd524bd9608fa6387623cfe492572722c0477470
# 8     Giridharan Kesavan  3           a72da1135b3362b641f751afa2c93962bd9ac746
# 9     Giridharan Kesavan  4           7e7fd2ce5b754c6398f8a326e5172d1e1b57c8e6
# ...                  ... ..                                                ...
# 9704  rohithsharmaks      5           dc76c4b035277f276bc575222d1536e199d719d7
# 9705  Vinayakumar B       115         f8932d478f5cbdc536559e06d539cd39b11eff33
# 9706  Arun Suresh         15          84ea7cd40883871caa657b154db9f6ab206b4ad3
# 9707  Junping Du          76          7af531d2e393185fa7dd32370f45dbb2a1d34df5
# 9708  Junping Du          77          c8469357bad481ca8e341050553a5ae6d98bf8e5
# 9709  Jing Zhao           237         2c694286b4a312bf3920c5b27e167af6ef66e13b
# 9710  Jing Zhao           238         d7d804623eb193fe27d690e374824622ba3d3a25
# 9711  Carlo Curino        1           8e23a7997fcc0fc17ee9725324ad745ec4b406e1
# 9712  Arpit Agarwal       198         42a05d29eeb61c6c01cfa56142bb05f38e162707
# 9713  Rohith Sharma K S   2           a0da1ec01051108b77f86799dd5e97563b2a3962
#
# [9714 rows x 3 columns]

# %%
df = pd.read_pickle("projectData/defectAuthorMatrix.p")
dF = pd.DataFrame(df, columns= ["parentCommit", "file", "lineNumber", "author", "implicated"])

# %%
hadoop1000Matrix = pd.read_pickle("projectData/defectAuthorMatrixForHADOOP1000.p")
hadoop1000 = pd.DataFrame(hadoop1000Matrix, columns= ["parentCommit", "file", "lineNumber", "author", "implicated"])

# %%
hadoop2000Matrix = pd.read_pickle("projectData/defectAuthorMatrixForHADOOP2000.p")
hadoop2000 = pd.DataFrame(hadoop1000Matrix, columns= ["parentCommit", "file", "lineNumber", "author", "implicated"])

# %%
hdfsMatrix = pd.read_pickle("projectData/defectAuthorMatrixForHDFS.p")
hdfs = pd.DataFrame(hdfsMatrix, columns= ["parentCommit", "file", "lineNumber", "author", "implicated"])

# %%
hdfs2000Matrix = pd.read_pickle("projectData/defectAuthorMatrixForHDFS2000.p")
hdfs2000 = pd.DataFrame(hdfs2000Matrix, columns= ["parentCommit", "file", "lineNumber", "author", "implicated"])

# %%
hdfs1000Matrix = pd.read_pickle("projectData/defectAuthorMatrixForHDFS1000.p")
hdfs1000 = pd.DataFrame(hdfs1000Matrix, columns= ["parentCommit", "file", "lineNumber", "author", "implicated"])

# %%
yarnMatrix = pd.read_pickle("projectData/defectAuthorMatrixForYARN.p")
yarn = pd.DataFrame(yarnMatrix, columns= ["parentCommit", "file", "lineNumber", "author", "implicated"])

# %%
yarn1000Matrix = pd.read_pickle("projectData/defectAuthorMatrixForYARN1000.p")
yarn1000 = pd.DataFrame(yarn1000Matrix, columns= ["parentCommit", "file", "lineNumber", "author", "implicated"])

# %%
mapreduceMatrix = pd.read_pickle("projectData/defectAuthorMatrixForMAPREDUCE.p")
mapreduce = pd.DataFrame(mapreduceMatrix, columns= ["parentCommit", "file", "lineNumber", "author", "implicated"])

# %%
mapreduce1000Matrix = pd.read_pickle("projectData/defectAuthorMatrixForMAPREDUCE1000.p")
mapreduce1000 = pd.DataFrame(mapreduce1000Matrix, columns= ["parentCommit", "file", "lineNumber", "author", "implicated"])

# %%
dF=pd.concat([dF, hadoop1000, hdfs, hdfs2000, hdfs1000, yarn, yarn1000, mapreduce, mapreduce1000])
dF
# Out:
#                                  parentCommit  \
# 0    52ee3ecdf683c6963c0e1a8e7567067320950d08
# 1    52ee3ecdf683c6963c0e1a8e7567067320950d08
# 2    6f50a6a4565d89a886a240c459899692ed5807c3
# 3    2ec008eb38b7a8b4dceb5e64c4c6d73fee147740
# 4    2ec008eb38b7a8b4dceb5e64c4c6d73fee147740
# 5    930e344d7885cc392eb3ee01e59b748f175fff21
# 6    930e344d7885cc392eb3ee01e59b748f175fff21
# 7    53ed25c3d19b4357c65da7d8ac61386077183d16
# 8    53ed25c3d19b4357c65da7d8ac61386077183d16
# 9    53ed25c3d19b4357c65da7d8ac61386077183d16
# ..                                        ...
# 590  504b801ca0e7fd3944872d3214539feb2d614f06
# 591  504b801ca0e7fd3944872d3214539feb2d614f06
# 592  504b801ca0e7fd3944872d3214539feb2d614f06
# 593  504b801ca0e7fd3944872d3214539feb2d614f06
# 594  504b801ca0e7fd3944872d3214539feb2d614f06
# 595  504b801ca0e7fd3944872d3214539feb2d614f06
# 596  504b801ca0e7fd3944872d3214539feb2d614f06
# 597  504b801ca0e7fd3944872d3214539feb2d614f06
# 598  504b801ca0e7fd3944872d3214539feb2d614f06
# 599  504b801ca0e7fd3944872d3214539feb2d614f06
#
#                                                                                                                 file  \
# 0    hadoop-common-project/hadoop-common/src/test/java/org/apache/hadoop/fs/contract/AbstractContractAppendTest.java
# 1    hadoop-common-project/hadoop-common/src/test/java/org/apache/hadoop/fs/contract/AbstractContractAppendTest.java
# 2    hadoop-common-project/hadoop-common/src/main/java/org/apache/hadoop/fs/permission/UmaskParser.java
# 3    hadoop-common-project/hadoop-common/src/main/java/org/apache/hadoop/fs/FsShell.java
# 4    hadoop-common-project/hadoop-common/src/test/java/org/apache/hadoop/tracing/SetSpanReceiver.java
# 5    hadoop-tools/hadoop-azure/src/main/java/org/apache/hadoop/fs/azure/NativeAzureFileSystem.java
# 6    hadoop-tools/hadoop-azure/src/main/java/org/apache/hadoop/fs/azure/NativeAzureFileSystem.java
# 7    hadoop-tools/hadoop-archives/src/main/java/org/apache/hadoop/tools/HadoopArchives.java
# 8    hadoop-tools/hadoop-archives/src/main/java/org/apache/hadoop/tools/HadoopArchives.java
# 9    hadoop-tools/hadoop-archives/src/main/java/org/apache/hadoop/tools/HadoopArchives.java
# ..                                                                                      ...
# 590  mapreduce/src/java/org/apache/hadoop/mapreduce/security/TokenCache.java
# 591  mapreduce/src/java/org/apache/hadoop/mapreduce/task/reduce/MergeManager.java
# 592  mapreduce/src/java/org/apache/hadoop/mapreduce/task/reduce/MergeManager.java
# 593  mapreduce/src/java/org/apache/hadoop/mapreduce/task/reduce/Shuffle.java
# 594  mapreduce/src/java/org/apache/hadoop/mapreduce/task/reduce/Shuffle.java
# 595  mapreduce/src/test/mapred/org/apache/hadoop/mapred/TestMapRed.java
# 596  mapreduce/src/test/mapred/org/apache/hadoop/mapreduce/security/TestBinaryTokenFile.java
# 597  mapreduce/src/test/mapred/org/apache/hadoop/mapreduce/security/TestTokenCache.java
# 598  mapreduce/src/test/mapred/org/apache/hadoop/mapreduce/security/TestTokenCache.java
# 599  mapreduce/src/test/mapred/org/apache/hadoop/security/TestMapredGroupMappingServiceRefresh.java
#
#      lineNumber                author  \
# 0    27          Steve Loughran
# 1    33          Steve Loughran
# 2    36          Suresh Srinivas
# 3    282         Colin Patrick Mccabe
# 4    89          Akira Ajisaka
# 5    1363        cnauroth
# 6    1364        cnauroth
# 7    103         Todd Lipcon
# 8    110         Andrew Wang
# 9    111         Andrew Wang
# ..   ...                 ...
# 590  110         Todd Lipcon
# 591  136         Todd Lipcon
# 592  149         Todd Lipcon
# 593  78          Todd Lipcon
# 594  98          Todd Lipcon
# 595  296         Todd Lipcon
# 596  181         Todd Lipcon
# 597  227         Todd Lipcon
# 598  230         Todd Lipcon
# 599  111         Todd Lipcon
#
#                                    implicated
# 0    6ba46c2dfc742e22ae9974c3fb5c64410971cd95
# 1    6ba46c2dfc742e22ae9974c3fb5c64410971cd95
# 2    cdbb724edbe093a02d4e2c24523001dcdff0ffd5
# 3    016c794e75be975078a5b422e79720bbc1044028
# 4    e397cca4569e17529a51d95142ebc1cf4c00e31b
# 5    5a737026cc365eb86c1d72c660fb13d8540a03b4
# 6    5a737026cc365eb86c1d72c660fb13d8540a03b4
# 7    a196766ea07775f18ded69bd9e8d239f8cfd3ccc
# 8    075bb9e380994a267ecba15b7e410f147dcfc35a
# 9    075bb9e380994a267ecba15b7e410f147dcfc35a
# ..                                        ...
# 590  a196766ea07775f18ded69bd9e8d239f8cfd3ccc
# 591  a196766ea07775f18ded69bd9e8d239f8cfd3ccc
# 592  a196766ea07775f18ded69bd9e8d239f8cfd3ccc
# 593  a196766ea07775f18ded69bd9e8d239f8cfd3ccc
# 594  a196766ea07775f18ded69bd9e8d239f8cfd3ccc
# 595  a196766ea07775f18ded69bd9e8d239f8cfd3ccc
# 596  a196766ea07775f18ded69bd9e8d239f8cfd3ccc
# 597  a196766ea07775f18ded69bd9e8d239f8cfd3ccc
# 598  a196766ea07775f18ded69bd9e8d239f8cfd3ccc
# 599  a196766ea07775f18ded69bd9e8d239f8cfd3ccc
#
# [7363 rows x 5 columns]

# %%
dF=dF.sort_index(axis=0 ,ascending=False)
dF= dF.reset_index(drop=True)
dF
# Out:
#                                   parentCommit  \
# 0     12f83b380a9bf55f793cc166f495ff543296e1dc
# 1     12f83b380a9bf55f793cc166f495ff543296e1dc
# 2     12f83b380a9bf55f793cc166f495ff543296e1dc
# 3     12f83b380a9bf55f793cc166f495ff543296e1dc
# 4     12f83b380a9bf55f793cc166f495ff543296e1dc
# 5     12f83b380a9bf55f793cc166f495ff543296e1dc
# 6     12f83b380a9bf55f793cc166f495ff543296e1dc
# 7     12f83b380a9bf55f793cc166f495ff543296e1dc
# 8     12f83b380a9bf55f793cc166f495ff543296e1dc
# 9     12f83b380a9bf55f793cc166f495ff543296e1dc
# ...                                        ...
# 7353  707b96fa5840873e6158ab49b7d66b72e5c0739d
# 7354  1619d8d62a7fb925dfe40d6bb06ed2c145e285ee
# 7355  8e23a7997fcc0fc17ee9725324ad745ec4b406e1
# 7356  0e7c88347e1c0b558866160d8c75d3b8ad3e6e1b
# 7357  a28e23d049478bf1210539bb60f0f262e8cefce2
# 7358  707b96fa5840873e6158ab49b7d66b72e5c0739d
# 7359  c3254a63a9943e5092fb416a8148dfd0bea51c13
# 7360  6772c3f4ddfc14645f26497d346708e910711366
# 7361  0e2019fa30bb05eff8ca6573b48210c0970f2b07
# 7362  52ee3ecdf683c6963c0e1a8e7567067320950d08
#
#                                                                                                                                                                                            file  \
# 0     hadoop-hdfs-project/hadoop-hdfs/src/test/java/org/apache/hadoop/hdfs/server/namenode/TestEditLog.java
# 1     hadoop-hdfs-project/hadoop-hdfs/src/test/java/org/apache/hadoop/hdfs/server/namenode/TestEditLog.java
# 2     hadoop-hdfs-project/hadoop-hdfs/src/test/java/org/apache/hadoop/hdfs/server/namenode/TestEditLog.java
# 3     hadoop-hdfs-project/hadoop-hdfs/src/test/java/org/apache/hadoop/hdfs/server/namenode/TestEditLog.java
# 4     hadoop-hdfs-project/hadoop-hdfs/src/test/java/org/apache/hadoop/hdfs/server/namenode/TestEditLog.java
# 5     hadoop-hdfs-project/hadoop-hdfs/src/test/java/org/apache/hadoop/hdfs/server/namenode/TestEditLog.java
# 6     hadoop-hdfs-project/hadoop-hdfs/src/test/java/org/apache/hadoop/hdfs/server/namenode/TestEditLog.java
# 7     hadoop-hdfs-project/hadoop-hdfs/src/test/java/org/apache/hadoop/hdfs/TestAbandonBlock.java
# 8     hadoop-hdfs-project/hadoop-hdfs/src/main/java/org/apache/hadoop/hdfs/server/namenode/INodeFileUnderConstruction.java
# 9     hadoop-hdfs-project/hadoop-hdfs/src/main/java/org/apache/hadoop/hdfs/server/namenode/INodeFileUnderConstruction.java
# ...                                                                                                                    ...
# 7353  hadoop-yarn-project/hadoop-yarn/hadoop-yarn-server/hadoop-yarn-server-resourcemanager/src/main/java/org/apache/hadoop/yarn/server/resourcemanager/scheduler/capacity/AbstractCSQueue.java
# 7354  hadoop-common-project/hadoop-common/src/main/java/org/apache/hadoop/metrics2/impl/MetricsSystemImpl.java
# 7355  hadoop-hdfs-project/hadoop-hdfs/src/main/java/org/apache/hadoop/hdfs/server/namenode/Checkpointer.java
# 7356  hadoop-hdfs-project/hadoop-hdfs/src/test/java/org/apache/hadoop/hdfs/TestDFSInotifyEventInputStream.java
# 7357  hadoop-yarn-project/hadoop-yarn/hadoop-yarn-server/hadoop-yarn-server-resourcemanager/src/main/java/org/apache/hadoop/yarn/server/resourcemanager/nodelabels/RMNodeLabelsManager.java
# 7358  hadoop-yarn-project/hadoop-yarn/hadoop-yarn-server/hadoop-yarn-server-resourcemanager/src/main/java/org/apache/hadoop/yarn/server/resourcemanager/scheduler/capacity/AbstractCSQueue.java
# 7359  hadoop-mapreduce-project/hadoop-mapreduce-client/hadoop-mapreduce-client-jobclient/src/test/java/org/apache/hadoop/hdfs/NNBench.java
# 7360  hadoop-hdfs-project/hadoop-hdfs-client/src/main/java/org/apache/hadoop/hdfs/web/ByteRangeInputStream.java
# 7361  hadoop-mapreduce-project/hadoop-mapreduce-client/hadoop-mapreduce-client-app/src/main/java/org/apache/hadoop/mapreduce/v2/app/MRAppMaster.java
# 7362  hadoop-common-project/hadoop-common/src/test/java/org/apache/hadoop/fs/contract/AbstractContractAppendTest.java
#
#       lineNumber                   author  \
# 0     295         Todd Lipcon
# 1     291         Todd Lipcon
# 2     278         Todd Lipcon
# 3     130         Todd Lipcon
# 4     129         Todd Lipcon
# 5     117         Todd Lipcon
# 6     115         Todd Lipcon
# 7     75          Todd Lipcon
# 8     45          Todd Lipcon
# 9     44          Todd Lipcon
# ...   ..                  ...
# 7353  57          Vinod Kumar Vavilapalli
# 7354  371         Arun Murthy
# 7355  257         Konstantin Shvachko
# 7356  167         Andrew Wang
# 7357  37          Wangda Tan
# 7358  56          Jian He
# 7359  62          Akira Ajisaka
# 7360  105         Tsz-wo Sze
# 7361  233         Siddharth Seth
# 7362  27          Steve Loughran
#
#                                     implicated
# 0     28e6a4e44a3e920dcaf858f9a74a6358226b3a63
# 1     a196766ea07775f18ded69bd9e8d239f8cfd3ccc
# 2     a196766ea07775f18ded69bd9e8d239f8cfd3ccc
# 3     a196766ea07775f18ded69bd9e8d239f8cfd3ccc
# 4     a196766ea07775f18ded69bd9e8d239f8cfd3ccc
# 5     a196766ea07775f18ded69bd9e8d239f8cfd3ccc
# 6     a196766ea07775f18ded69bd9e8d239f8cfd3ccc
# 7     a196766ea07775f18ded69bd9e8d239f8cfd3ccc
# 8     a196766ea07775f18ded69bd9e8d239f8cfd3ccc
# 9     a196766ea07775f18ded69bd9e8d239f8cfd3ccc
# ...                                        ...
# 7353  e8e3a36213936f69efdc765103700acdc2ac9d5a
# 7354  827401a9b1d85fe1f443d21ebe9d917ba23153de
# 7355  4688f839d23a94e8da84e65adcd95e6f896ad379
# 7356  958c9b5080d584c2e60fa2e1a041e5dc5f7498eb
# 7357  8857cba72e70842ac6ffc593a1c98577850f2572
# 7358  1c601e492f4cd80e012aa78b796383ee9de161fd
# 7359  98446ee695f922ab079654bbc6d613ab334e371f
# 7360  73c378c1e7819c63501ea7f4f15d40d0a55caadc
# 7361  422133edf777209014455a4e397a05d8a4e4c431
# 7362  6ba46c2dfc742e22ae9974c3fb5c64410971cd95
#
# [7363 rows x 5 columns]

# %%
implicatedList = dF['implicated'].tolist()
# # dF[['name','commits']]= pd.DataFrame(dF.name.tolist(), index=dF.index)

tempList=[]
commits=experienceCommits['commits'].tolist()
for x in commits:
    if x in implicatedList:
        tempList.append([x, True])
    else:
        tempList.append([x, False])
        

s=pd.DataFrame(tempList, columns=['commit', 'buggy'])
experienceCommits[['buggy']]=pd.DataFrame(s['buggy'])
experienceCommits['buggy'] = experienceCommits.buggy.astype(int)

# %%
data= dF.groupby('author')['implicated'].nunique()
authorDf = pd.DataFrame(data)
topBugyContributers= authorDf.implicated.nlargest(15)
tempBuggy=[]
for author in topBugyContributers.index:
    tempBuggy= experienceCommits.loc[(experienceCommits['name']==author) & (experienceCommits["buggy"]==1)]
    tempDf = pd.DataFrame(tempBuggy['buggy'].cumsum())
#     tempBuggy[['cumBuggy']]=0
    tempBuggy[['cumBuggy']]= tempDf
    print("author name", author)
    pt.plot(tempBuggy['experience'], tempBuggy['cumBuggy'], label= str(author))
    pt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    
# Not plotting the non buggy commits, only the buggy commits, which is why this is a smooth curve. 
# I am filtering the experience matrix first based on the buggyiness.
# Out:
# author name Vinod Kumar Vavilapalli
# author name Tsz-wo Sze
# author name Suresh Srinivas
# author name Alejandro Abdelnur
# author name Jing Zhao
# author name Arun Murthy
# author name Haohui Mai
# author name Todd Lipcon
# author name Jian He
# author name Andrew Wang
# author name Karthik Kambatla
# author name Colin Patrick Mccabe
# author name Arpit Agarwal
# author name Eli Collins
# author name Sanford Ryza

# %%
import math
authorDf.implicated.hist(bins=15, grid=False)
locs, label= pt.yticks()
print(locs, label)
yint=[]
for each in locs:
    yint.append(int(each))
pt.yticks(yint)


pt.savefig('histDefects.pdf', bbox_inches="tight")
# Out:
# [ 0.  5. 10. 15. 20. 25. 30. 35. 40.] <a list of 9 Text yticklabel objects>

# %%
topContributors= experienceCommits.groupby('name')['commits']
topContributors=topContributors.nunique().nlargest(5)
# topContributors.columns=['somethingelse']
# topContributors
# tempBuggy= dF.loc[dF['author'].isin(topContributors.index)]
# tempBuggy.groupby('author')['implicated'].nunique().nsmallest(2)

# %%
tempBuggy=[]
for author in topContributors.index:
    tempBuggy= experienceCommits.loc[(experienceCommits['name']==author)]
    tempDf= pd.DataFrame(tempBuggy['buggy'].cumsum())
    # tempDf = pd.DataFrame(tempBuggy['buggy'].cumsum())
    # tempBuggy[['cumBuggy']]=0
    tempBuggy[['cumBuggy']]= tempDf
    print("author name", author)
    pt.plot(tempBuggy['experience'], tempBuggy['cumBuggy'], label= str(author))
    pt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    
pt.title("author with most experience and their bug plot")
# Out:
# author name Vinod Kumar Vavilapalli
# author name Tsz-wo Sze
# author name Alejandro Abdelnur
# author name Eli Collins
# author name Arun Murthy
# Text(0.5, 1.0, 'author with most experience and their bug plot')

# %%
data= dF.groupby('author')['implicated'].nunique()
authorDf = pd.DataFrame(data)
topBugyContributers= authorDf.implicated.nlargest(5)
tempBuggy=[]
for author in topBugyContributers.index:
    tempBuggy= experienceCommits.loc[(experienceCommits['name']==author)]
    tempDf= pd.DataFrame(tempBuggy['buggy'].cumsum())
    # tempDf = pd.DataFrame(tempBuggy['buggy'].cumsum())
    # tempBuggy[['cumBuggy']]=0
    tempBuggy[['cumBuggy']]= tempDf
    print("author name", author)
    pt.plot(tempBuggy['experience'], tempBuggy['cumBuggy'], label= str(author))
    pt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    
pt.title("author with most bugs vs experience")
# Out:
# author name Vinod Kumar Vavilapalli
# author name Tsz-wo Sze
# author name Suresh Srinivas
# author name Alejandro Abdelnur
# author name Jing Zhao
# Text(0.5, 1.0, 'author with most bugs vs experience')

# %%
data= dF.groupby('author')['implicated'].nunique()
authorDf = pd.DataFrame(data)
topBugyContributers= authorDf.implicated.nsmallest(5)
tempBuggy=[]
for author in topBugyContributers.index:
    tempBuggy= experienceCommits.loc[(experienceCommits['name']==author)]
    tempDf= pd.DataFrame(tempBuggy['buggy'].cumsum())
    # tempDf = pd.DataFrame(tempBuggy['buggy'].cumsum())
    # tempBuggy[['cumBuggy']]=0
    tempBuggy[['cumBuggy']]= tempDf
    print("author name", author)
    pt.plot(tempBuggy['experience'], tempBuggy['cumBuggy'], label= str(author))
    pt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

pt.title("author with least bugs")
# Out:
# author name Arun Suresh
# author name Benoy Antony
# author name Dongming Liang
# author name Gera Shegalov
# author name Giridharan Kesavan
# Text(0.5, 1.0, 'author with least bugs')

# %%
topContributors= experienceCommits.groupby('name')['commits']
topContributors=topContributors.nunique().nlargest(10)
topContributors.columns=['somethingelse']
topContributors
tempBuggy= dF.loc[dF['author'].isin(topContributors.index)]
bottomBuggyContributor = tempBuggy.groupby('author')['implicated'].nunique().nsmallest(5)

tempBuggy=[]
for author in bottomBuggyContributor.index:
    tempBuggy= experienceCommits.loc[(experienceCommits['name']==author)]
    tempDf= pd.DataFrame(tempBuggy['buggy'].cumsum())
    # tempDf = pd.DataFrame(tempBuggy['buggy'].cumsum())
    # tempBuggy[['cumBuggy']]=0
    tempBuggy[['cumBuggy']]= tempDf
    print("author name", author)
    pt.plot(tempBuggy['experience'], tempBuggy['cumBuggy'], label= str(author))
    pt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    pt.title("author with most contributions but with least bugs")
# Out:
# author name Robert Joseph Evans
# author name Aaron Myers
# author name Eli Collins
# author name Todd Lipcon
# author name Haohui Mai
